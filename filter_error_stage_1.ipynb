# %%
import os
import json
import pandas as pd

# %%
data_path = 'label_3h_150524'

# %%
data = sorted(os.listdir(data_path))

# %%
data_folder = 'label_3h_150524'

data_paths = sorted(os.listdir(data_folder))

# read all files as jsonl

data = []
for i in data_paths:
    with open(os.path.join(data_folder, i), 'r', encoding='utf-8') as f:
        tmp = json.load(f)
        data.append(tmp)

# %%
s = data[0]['text']
for i in data[0]['label']:
    print(s[i[0]:i[1]], i[2])
# Out:
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Văn T PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Thị S PER
# Nguyễn Văn T2 PER
# Nguyễn Văn T2 PER
# Nguyễn Văn T2 PER
# Nguyễn Văn T2 PER
# Nguyễn Văn Q PER
# Nguyễn Văn Q PER
# Nguyễn Duy K PER
# Trương Thị X PER
# Trương Thị X PER
# Trương Thị X PER
# Bùi Quang N PER
# Bùi Quang N PER
# Nguyễn Thanh T1 PER
# Nguyễn Thanh T1 PER
# Nguyễn Thị N H PER
# TÒA ÁN NHÂN DÂN TỈNH TIỀN GIANG ORG
# Toà án nhân dân huyện C ORG
# Toà án nhân dân huyện C ORG
# Toà án nhân dân huyện C ORG
# Toà án nhân dân huyện C ORG
# Đoàn Luật sư tỉnh Tiền Giang ORG
# Công ty TN Đo đạc Đông ải ORG
# Công ty TN Đo đạc Đông ải ORG
# Công ty TN Đo đạc Đông ải ORG
# Công ty TN Đo đạc Đông ải ORG
# Ủy ban nhân dân huyện C ORG
# Ủy ban nhân dân huyện C ORG
# Ủy ban nhân dân huyện C ORG
# Ủy ban nhân dân huyện C ORG
# Thẩm phán ORG
# Bộ luật Tố tụng dân sự ORG
# Bộ luật Tố tụng dân sự ORG
# Bộ luật Tố tụng dân sự ORG
# Bộ luật Tố tụng dân sự ORG
# Bộ luật Tố tụng dân sự ORG
# Bộ luật Tố tụng dân sự ORG
# Bộ luật Tố tụng dân sự ORG
# Bộ luật Tố tụng dân sự ORG
# Bộ luật Dân sự ORG
# Bộ luật Dân sự ORG
# Bộ luật Dân sự ORG
# Bộ luật Dân sự ORG
# Bộ luật Dân sự ORG
# Ủy ban Thường vụ Quốc hội ORG
# Ủy ban Thường vụ Quốc hội ORG
# Chi cục Thi hành án dân sự huyện C ORG
# Chi cục Thi hành án dân sự huyện C ORG
# Luật Thi hành án dân sự ORG
# Luật Thi hành án dân sự ORG
# Luật Thi hành án dân sự ORG
# Ấp B LOC
# Ấp B LOC
# Ấp B LOC
# xã T LOC
# xã T LOC
# xã T LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# huyện C LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# tỉnh Tiền Giang LOC
# Ấp M LOC
# xã H LOC
# khu B LOC
# xã LOC
# xã LOC
# xã LOC
# xã LOC
# ấp B LOC
# ấp B LOC
# ấp B LOC
# ấp B LOC
# ấp B LOC
# 25/08/2023 TIME
# 11/01/2023 TIME
# 11/01/2023 TIME
# 25 tháng 8 năm 2023 TIME
# 29/10/2014 TIME
# 29/10/2014 TIME
# 29/10/2014 TIME
# 29/10/2014 TIME
# 29/10/2014 TIME
# 2017 TIME
# 2017 TIME
# 17 tháng 01 năm 2023 TIME
# 172.174.670 đồng AMT
# 172.174.670 đồng AMT
# 200.000.000 đồng AMT
# 200.000.000 đồng AMT
# 200.000.000 đồng AMT
# 200.000.000 đồng AMT
# 200.000.000 đồng AMT
# 300.000 đồng AMT
# 300.000 đồng AMT
# 300.000 đồng AMT
# 300.000 đồng AMT
# 300.000 đồng AMT
# 300.000 đồng AMT
# 10.000.000 đồng AMT
# 10.000.000 đồng AMT
# 9.700.000 đồng AMT
# 461/2023/DS-PT DOC_ID
# 461/2023/DS-PT DOC_ID
# 495/2023/QĐ-PT DOC_ID
# 07/2023/DS-ST DOC_ID
# 07/2023/DS-ST DOC_ID
# 07/2023/DS-ST DOC_ID
# 07/2023/DS-ST DOC_ID
# 10864 DOC_ID
# 1195 DOC_ID
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Nguyễn Văn T PETITIONER
# Trương Thị X PETITIONER
# Trương Thị X PETITIONER
# Trương Thị X PETITIONER
# Nguyễn Văn T2 PETITIONER
# Nguyễn Văn T2 PETITIONER
# Nguyễn Văn T2 PETITIONER
# Nguyễn Văn T2 PETITIONER
# Nguyễn Văn Q PETITIONER
# Nguyễn Văn Q PETITIONER
# Nguyễn Duy K PETITIONER
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# Nguyễn Thị S RESPONDENT
# TÒA ÁN NHÂN DÂN TỈNH TIỀN GIANG COURT
# Toà án nhân dân huyện C, tỉnh Tiền Giang COURT
# Toà án nhân dân huyện C, tỉnh Tiền Giang COURT
# Toà án nhân dân huyện C, tỉnh Tiền Giang COURT
# Toà án nhân dân huyện C, tỉnh Tiền Giang COURT
# Bộ luật Dân sự STATUTE
# Bộ luật Dân sự STATUTE
# Bộ luật Dân sự STATUTE
# Bộ luật Dân sự STATUTE
# Bộ luật Dân sự STATUTE
# Luật Đất đai STATUTE
# Luật Đất đai STATUTE
# Bộ luật Tố tụng dân sự STATUTE
# Bộ luật Tố tụng dân sự STATUTE
# Bộ luật Tố tụng dân sự STATUTE
# Bộ luật Tố tụng dân sự STATUTE
# Bộ luật Tố tụng dân sự STATUTE
# Bộ luật Tố tụng dân sự STATUTE
# Bộ luật Tố tụng dân sự STATUTE
# Bộ luật Tố tụng dân sự STATUTE
# quyền sử dụng đất RIGHT
# quyền sử dụng đất RIGHT
# quyền sử dụng đất RIGHT
# quyền sử dụng đất RIGHT
# quyền sử dụng đất RIGHT
# quyền sử dụng đất RIGHT
# quyền sử dụng đất RIGHT
# quyền sử dụng đất RIGHT
# quyền sử dụng đất RIGHT
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Thị S VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Nguyễn Văn T VICTIM
# Ấp B CRIME_LOCATION
# Ấp B CRIME_LOCATION
# Ấp B CRIME_LOCATION
# x T CRIME_LOCATION
# x T CRIME_LOCATION
# x T CRIME_LOCATION
# x T CRIME_LOCATION
# x T CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# huyện C CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
# tỉnh Tiền Giang CRIME_LOCATION
